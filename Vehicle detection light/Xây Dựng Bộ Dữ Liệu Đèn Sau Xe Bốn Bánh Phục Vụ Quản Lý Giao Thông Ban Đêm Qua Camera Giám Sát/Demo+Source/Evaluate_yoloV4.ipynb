# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
with open("yolov4-fileloss.log") as f:
    f = f.readlines()
lines = []
for line in f:
    if "avg" in line:
        lines.append(line)

# %%
iterations = []
avg_loss = []
print('Retrieving data and plotting training loss graph...')
for i in range(len(lines)):
    lineParts = lines[i].split(',')
    iterations.append(int(lineParts[0].split(':')[0]))
    avg_loss.append(float(lineParts[1].split()[0]))
fig = plt.figure()
plt.figure(figsize=(7.5,5))
for i in range(0, len(lines)):
    plt.plot(iterations[i:i+2], avg_loss[i:i+2], 'r-',linewidth=1)
plt.xlabel('Batch Number')
plt.ylabel('Avg Loss')
fig.savefig('training_loss_plot.png')
print('Done! Plot saved as training_loss_plot.png')
# Out:
# Retrieving data and plotting training loss graph...
# Done! Plot saved as training_loss_plot.png

# %%
def imShow(path):
    # %matplotlib inline
    image = cv2.imread(path)
    height, width = image.shape[:2]
    resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)
    fig = plt.gcf()
    fig.set_size_inches(18, 10)
    plt.axis("off")
    #plt.rcParams['figure.figsize'] = [10, 5]
    plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
    plt.show()

# %%
mAP = [74.31,96.30,96.60,97.82,98.80,98.80]
IoU = [54.03,69.27,73.08,75.24,78.30,78.76]
a=[1000,2000,3000,4000,5000,6000]

# %%
fig = plt.figure()
plt.figure(figsize=(7.5,5))
plt.plot(a,mAP,'^-',label='mAP',linewidth=1)
plt.plot(a,IoU,'o-',label='IoU',linewidth=1)
plt.xlabel('Iteration')
plt.ylabel('%')
plt.legend(loc='lower right')
fig.savefig('haha.png',dpi=1000)
