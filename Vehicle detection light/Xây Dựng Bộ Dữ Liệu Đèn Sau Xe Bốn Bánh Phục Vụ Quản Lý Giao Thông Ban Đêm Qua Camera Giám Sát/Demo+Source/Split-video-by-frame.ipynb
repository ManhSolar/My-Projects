# %%
import cv2
vidcap = cv2.VideoCapture('IMG_1122 (online-video-cutter.com).mp4')
success, image = vidcap.read()
count = 0
while success:
  cv2.imwrite("image_%d.jpg" % count, image)    
  success, image = vidcap.read()
  print('Saved image ', count)
  count += 1
# Out:
# Saved image  829
# Saved image  830
# Saved image  831
# Saved image  832
# Saved image  833
# Saved image  834
# Saved image  835
# Saved image  836
# Saved image  837
# Saved image  838
# Saved image  839
# Saved image  840
# Saved image  841
# Saved image  842
# Saved image  843
# Saved image  844
# Saved image  845
# Saved image  846
# Saved image  847
# Saved image  848
# Saved image  849
# Saved image  850
# Saved image  851
# Saved image  852
# Saved image  853
# Saved image  854
# Saved image  855
# Saved image  856
# Saved image  857
# Saved image  858
# Saved image  859
# Saved image  860
# Saved image  861
# Saved image  862
# Saved image  863
# Saved image  864
# Saved image  865
# Saved image  866
# Saved image  867
# Saved image  868
# Saved image  869
# Saved image  870
# Saved image  871
# Saved image  872
# Saved image  873
# Saved image  874
# Saved image  875
# Saved image  876
# Saved image  877
# Saved image  878
# Saved image  879
# Saved image  880
# ...

# %%
count
# Out:
# 1
